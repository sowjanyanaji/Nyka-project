# %%
import numpy as np
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Category: Energy Boosters

# %%
title = []
ogprice = []
price = []
disc = []
feature = []
numratings = []


for i in range(1,24):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.text)
    for Title in soup.find_all('div', class_='css-xrzmfa'):
        T = (Title.text)
        if T:
            title.append(T)
        else:
            title.append(np.nan)
##################################################################
    for i in soup.find_all('div', class_="css-1d0jf8e"):
        discount = i.find('span', class_="css-cjd9an")
        og = i.find('span', class_="css-17x46n5")
        nodisc = i.find('span', class_='css-111z9ua')
        if discount in i:#prods w/ discount
            ogprice.append(og.text)
        elif og:
            ogprice.append(nodisc.text)
        else:
            ogprice.append(np.nan)
##################################################################
    for i in soup.find_all('span', class_="css-111z9ua"):
        Price =(i.text)
        if Price:
            price.append(Price)
        else:
            price.append(np.nan)

##################################################################           
    for feat in soup.find_all('div',class_='css-wkluxr'):
        if feat:
            f= feat.find('ul',class_='css-ycjyr6')
            if f:
                li_elements = f.find_all('li', class_='custom-tag')
                
                if li_elements:
                    featured_present = any("FEATURED" in li.text for li in li_elements)
                    bestseller_present = any("BESTSELLER" in li.text for li in li_elements)

                    if featured_present and bestseller_present:
                        feature.append("FEATURED & BESTSELLER")
                    elif featured_present:
                        feature.append("FEATURED")
                    elif bestseller_present:
                        feature.append("BESTSELLER")
                    else:
                        feature.append(np.nan)
                else:
                    feature.append(np.nan)
            else:
                feature.append(np.nan)
        else:
            feature.append(np.nan)
##################################################################
    for prods in soup.find_all('div', class_="css-d5z3ro"):
        ratings = prods.find('div', class_="css-wskh5y")
        if ratings:
            numratings.append(ratings.text)
        else:
            numratings.append(np.nan)
##################################################################
ratings = []

for i in range(1,24):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop'
    page = requests.get(url)
    soup = BeautifulSoup(page.content)
    for elements in soup.find_all('div', class_="css-d5z3ro"):#product
        reviews = elements.find('div', class_="css-wskh5y")#reviews
        if reviews:
            starElements = reviews.find_all('span',class_='star-wrap')
            count=0
            for star in starElements:
                res = star.find("path", {'fill-rule':'evenodd'})
                if res:
                    count=count+1
                else:
                    continue
            ratings.append(count)
        else:
            ratings.append(np.nan)
# Out:
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200
# page 8 status code:  200
# page 9 status code:  200
# page 10 status code:  200
# page 11 status code:  200
# page 12 status code:  200
# page 13 status code:  200
# page 14 status code:  200
# page 15 status code:  200
# page 16 status code:  200
# page 17 status code:  200
# page 18 status code:  200
# page 19 status code:  200
# page 20 status code:  200
# page 21 status code:  200
# page 22 status code:  200
# page 23 status code:  200

# %%
category = []
cat = 'Energy-boosters'

for i in range(len(title)):
    category.append(cat)

# %%
uni=[]
unititle = []
gen = 'Unisex'
for i in range(1,16):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&gender_filter=10712'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            uni.append(gen)
            unititle.append(j.text)

# %%
femprod = []
femtitle = []
gen = 'Female'
for i in range(1,6):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&gender_filter=10711'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            femprod.append(gen)
            femtitle.append(j.text)

# %%
maleprod = []
maletitle = []
gen = 'Male'
for i in range(1,3):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&gender_filter=10710'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            maleprod.append(gen)
            maletitle.append(j.text)

# %%
Gender = []

for i in title:
    if i in unititle:
        Gender.append('Unisex')
    elif i in femtitle:
        Gender.append('Female')
    elif i in maletitle:
        Gender.append('Male')
    else:
        Gender.append('Others')

# %%
captitle = []
form = 'Capsule'
for i in range(1,10):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10830'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            captitle.append(j.text)
            
tabtitle = []
form = 'Tablet'
for i in range(1,10):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=12424'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            tabtitle.append(j.text)

powtitle = []
form = 'Powder'
for i in range(1,3):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10812'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            powtitle.append(j.text)

geltitle = []
form = 'Gel'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10824'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            geltitle.append(j.text)

liqtitle = []
form = 'Liquid'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10822'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            liqtitle.append(j.text)

sttitle = []
form = 'Stick'
for i in range(1,2):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10804'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            sttitle.append(j.text)

oiltitle = []
form = 'Oil'
for i in range(1,2):
    url = f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10817'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            oiltitle.append(j.text)

# %%
Formulation = []

for i in title:
    if i in captitle:
        Formulation.append('Capsule')
    elif i in tabtitle:
        Formulation.append('Tablet')
    elif i in powtitle:
        Formulation.append('Powder')
    elif i in geltitle:
        Formulation.append('Gel')
    elif i in liqtitle:
        Formulation.append('Liquid')
    elif i in sttitle:
        Formulation.append('Stick')
    elif i in oiltitle:
        Formulation.append('Oil')
    else:
        Formulation.append('Others')

# %%
data = {'Product_Title':title,
        'Original Price': ogprice,
       'Discounted Price':price,
       'Additional_Tags':feature,
        'Ratings':ratings,
       'Number_of_ratings':numratings,
       'Gender':Gender,
       'Category':category,
       'Formulation':Formulation}

# %%
data
# Out:
# {'Product_Title': ['Wellbeing Nutrition Daily Greens Wholefood Multivitamin for ...',
#   'HealthKart HK Vitals Multivitamin for Women, Boosts Energy, ...',
#   "GNC Women's One Daily Multivitamin For Women",
#   "Oziva Daily Women's Multivitamin Tablets For Energy",
#   'Carbamide Forte Novosules Woman+ Multivitamin for Women with...',
#   "Swisse Women's Multivitamin for Energy, Stamina, Vitality an...",
#   'Zingavita Multivitamin Tablets For Women - For Skin, Energy,...',
#   "Wellwoman Supplements UK's No.1 Multivitamin for Women (Even...",
#   'MuscleBlaze Daily Multivitamin for Women',
#   'Purna Gummies Multivitamin Strawberry Gummies with Vitamins ...',
#   'Purna Gummies Kids Multivitamin Gummies for Growth, Immunity...',
#   'HealthKart Hk Vitals Multivitamin For Women, Boosts Energy, ...',
#   'Purna Gummies Multivitamin Mango Gummies with Vitamins & Min...',
#   'Be Bodywise Healthy & Nourished Hair Kit - Biotin Hair Gummi...',
# ...

# %%
len(title),len(ogprice),len(price),len(feature),len(ratings), len(category), len(Formulation),len(Gender)
# Out:
# (456, 456, 456, 456, 456, 456, 456, 456)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                          Product_Title Original Price  \
# 0    Wellbeing Nutrition Daily Greens Wholefood Mul...      MRP:₹1180
# 1    HealthKart HK Vitals Multivitamin for Women, B...       MRP:₹529
# 2         GNC Women's One Daily Multivitamin For Women      MRP:₹1449
# 3    Oziva Daily Women's Multivitamin Tablets For E...       MRP:₹499
# 4    Carbamide Forte Novosules Woman+ Multivitamin ...       MRP:₹770
# ..                                                 ...            ...
# 451  HealthVit Femyvit Women Multivitamins Tablets ...           ₹600
# 452  HealthVit MULVIT Multivitamins & Minerals 120 ...           ₹800
# 453  Top Gummy Adults Daily Multivitamin & Hair Nut...           ₹900
# 454  HealthVit Cenvitan Plant Based Whole Food Mult...          ₹1550
# 455  HealthVit Cenvitan Multivitamins & Multiminera...          ₹1050
#
#     Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %% [markdown]
# ### Immunity Boosters

# %%
title = []
ogprice = []
price = []
disc = []
feature = []
numratings = []


for i in range(1,12):
    url = f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.text)
    for Title in soup.find_all('div', class_='css-xrzmfa'):
        T = (Title.text)
        if T:
            title.append(T)
        else:
            title.append(np.nan)
##################################################################
    for i in soup.find_all('div', class_="css-1d0jf8e"):
        discount = i.find('span', class_="css-cjd9an")
        og = i.find('span', class_="css-17x46n5")
        nodisc = i.find('span', class_='css-111z9ua')
        if discount in i:#prods w/ discount
            ogprice.append(og.text)
        elif og:
            ogprice.append(nodisc.text)
        else:
            ogprice.append(np.nan)
##################################################################
    for i in soup.find_all('span', class_="css-111z9ua"):
        Price =(i.text)
        if Price:
            price.append(Price)
        else:
            price.append(np.nan)

##################################################################           
    for feat in soup.find_all('div',class_='css-wkluxr'):
        if feat:
            f= feat.find('ul',class_='css-ycjyr6')
            if f:
                li_elements = f.find_all('li', class_='custom-tag')
                
                if li_elements:
                    featured_present = any("FEATURED" in li.text for li in li_elements)
                    bestseller_present = any("BESTSELLER" in li.text for li in li_elements)

                    if featured_present and bestseller_present:
                        feature.append("FEATURED & BESTSELLER")
                    elif featured_present:
                        feature.append("FEATURED")
                    elif bestseller_present:
                        feature.append("BESTSELLER")
                    else:
                        feature.append(np.nan)
                else:
                    feature.append(np.nan)
            else:
                feature.append(np.nan)
        else:
            feature.append(np.nan)
##################################################################
    for prods in soup.find_all('div', class_="css-d5z3ro"):
        ratings = prods.find('div', class_="css-wskh5y")
        if ratings:
            numratings.append(ratings.text)
        else:
            numratings.append(np.nan)
##################################################################
ratings = []

for i in range(1,12):
    url = f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop'
    page = requests.get(url)
    soup = BeautifulSoup(page.content)
    for elements in soup.find_all('div', class_="css-d5z3ro"):#product
        reviews = elements.find('div', class_="css-wskh5y")#reviews
        if reviews:
            starElements = reviews.find_all('span',class_='star-wrap')
            count=0
            for star in starElements:
                res = star.find("path", {'fill-rule':'evenodd'})
                if res:
                    count=count+1
                else:
                    continue
            ratings.append(count)
        else:
            ratings.append(np.nan)
# Out:
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200
# page 8 status code:  200
# page 9 status code:  200
# page 10 status code:  200
# page 11 status code:  200

# %%
category = []
cat = 'Immunity-boosters'

for i in range(len(title)):
    category.append(cat)

# %%
uni=[]
unititle = []
gen = 'Unisex'
for i in range(1,11):
    url = f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            uni.append(gen)
            unititle.append(j.text)

# %%
femprod = []
femtitle = []
gen = 'Female'
for i in range(1,2):
    url = f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            femprod.append(gen)
            femtitle.append(j.text)

# %%
Gender = []

for i in title:
    if i in unititle:
        Gender.append('Unisex')
    elif i in femtitle:
        Gender.append('Female')
    else:
        Gender.append('Others')

# %%
captitle = []
#form = 'Capsule'
for i in range(1,4):
    url =f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop&formulation_filter=10830'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            captitle.append(j.text)
            
tabtitle = []
#form = 'Tablet'
for i in range(1,6):
    url =f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop&formulation_filter=12424'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            tabtitle.append(j.text)

powtitle = []
#form = 'Powder'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop&formulation_filter=10812'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            powtitle.append(j.text)

'''geltitle = []
#form = 'Gel'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10824'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            geltitle.append(j.text)
'''
liqtitle = []
#form = 'Liquid'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop&formulation_filter=10822'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            liqtitle.append(j.text)
            
crtitle = []
#form = 'Cream'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop&formulation_filter=10827'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            crtitle.append(j.text)
            

masktitle = []
#form = 'Mask'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/immunity-boosters-vitamin-c/c/18543?page_no={i}&sort=popularity&transaction_id=b3ce75b08e8a030f2f284102b9ea2768&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Better%20Immunity:-1:b3ce75b08e8a030f2f284102b9ea2768&eq=desktop&formulation_filter=10820'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            masktitle.append(j.text)

# %%
Formulation = []

for i in title:
    if i in captitle:
        Formulation.append('Capsule')
    elif i in tabtitle:
        Formulation.append('Tablet')
    elif i in powtitle:
        Formulation.append('Powder')
    elif i in geltitle:
        Formulation.append('Gel')
    elif i in liqtitle:
        Formulation.append('Liquid')
    elif i in sttitle:
        Formulation.append('Stick')
    elif i in oiltitle:
        Formulation.append('Oil')
    else:
        Formulation.append('Others')

# %%
len(Formulation)
# Out:
# 220

# %%
ibdata ={'Product_Title':title,
        'Original Price': ogprice,
       'Discounted Price':price,
       'Additional_Tags':feature,
        'Ratings':ratings,
       'Number_of_ratings':numratings,
       'Gender':Gender,
       'Category':category,
       'Formulation':Formulation}

# %%
ibdf = pd.DataFrame(ibdata)

# %%
ibdf
# Out:
#                                          Product_Title Original Price  \
# 0    Chicnutrix Super C - Amla Extract & Zinc - Vit...      MRP:₹1170
# 1    OZiva Bettr.C+, Plant-Based Vitamin C, Zinc & ...       MRP:₹599
# 2                    GNC Immune Formula 1000mg Tablets       MRP:₹999
# 3    Wellbeing Nutrition Melts Vital Iron + Folic A...       MRP:₹699
# 4    Setu Skin Renew Glutathione With Vitamin C For...      MRP:₹2200
# ..                                                 ...            ...
# 215  Fixuphealth Natural Amla 1000mg Vit C Zinc Eff...       MRP:₹369
# 216  Fixuphealth Japanese Matcha Green Tea With Ash...       MRP:₹499
# 217  Fixuphealth Japanese Matcha Green Tea With Ash...       MRP:₹998
# 218  Fixuphealth Japanese Matcha Green Tea With Ash...      MRP:₹1497
# 219  Fixuphealth Glutathione Vit C Aloe Vera Skin E...      MRP:₹2100
#
#     Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %% [markdown]
# ### Hormonal Balance

# %%
title = []
ogprice = []
price = []
disc = []
feature = []
numratings = []


for i in range(1,8):
    url = f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.text)
    for Title in soup.find_all('div', class_='css-xrzmfa'):
        T = (Title.text)
        if T:
            title.append(T)
        else:
            title.append(np.nan)
##################################################################
    for i in soup.find_all('div', class_="css-1d0jf8e"):
        discount = i.find('span', class_="css-cjd9an")
        og = i.find('span', class_="css-17x46n5")
        nodisc = i.find('span', class_='css-111z9ua')
        if discount in i:#prods w/ discount
            ogprice.append(og.text)
        elif og:
            ogprice.append(nodisc.text)
        else:
            ogprice.append(np.nan)
##################################################################
    for i in soup.find_all('span', class_="css-111z9ua"):
        Price =(i.text)
        if Price:
            price.append(Price)
        else:
            price.append(np.nan)

##################################################################           
    for feat in soup.find_all('div',class_='css-wkluxr'):
        if feat:
            f= feat.find('ul',class_='css-ycjyr6')
            if f:
                li_elements = f.find_all('li', class_='custom-tag')
                
                if li_elements:
                    featured_present = any("FEATURED" in li.text for li in li_elements)
                    bestseller_present = any("BESTSELLER" in li.text for li in li_elements)

                    if featured_present and bestseller_present:
                        feature.append("FEATURED & BESTSELLER")
                    elif featured_present:
                        feature.append("FEATURED")
                    elif bestseller_present:
                        feature.append("BESTSELLER")
                    else:
                        feature.append(np.nan)
                else:
                    feature.append(np.nan)
            else:
                feature.append(np.nan)
        else:
            feature.append(np.nan)
##################################################################
    for prods in soup.find_all('div', class_="css-d5z3ro"):
        ratings = prods.find('div', class_="css-wskh5y")
        if ratings:
            numratings.append(ratings.text)
        else:
            numratings.append(np.nan)
##################################################################
ratings = []

for i in range(1,8):
    url = f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop'
    page = requests.get(url)
    soup = BeautifulSoup(page.content)
    for elements in soup.find_all('div', class_="css-d5z3ro"):#product
        reviews = elements.find('div', class_="css-wskh5y")#reviews
        if reviews:
            starElements = reviews.find_all('span',class_='star-wrap')
            count=0
            for star in starElements:
                res = star.find("path", {'fill-rule':'evenodd'})
                if res:
                    count=count+1
                else:
                    continue
            ratings.append(count)
        else:
            ratings.append(np.nan)
# Out:
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200

# %%
category = []
cat = 'Hormonal-Balance'

for i in range(len(title)):
    category.append(cat)

# %%
uni=[]
unititle = []
gen = 'Unisex'
for i in range(1,3):
    url = f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop&gender_filter=10712'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            uni.append(gen)
            unititle.append(j.text)

# %%
femprod = []
femtitle = []
gen = 'Female'
for i in range(1,6):
    url=f"https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop&gender_filter=10711"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            femprod.append(gen)
            femtitle.append(j.text)

# %%
Gender = []

for i in title:
    if i in unititle:
        Gender.append('Unisex')
    elif i in femtitle:
        Gender.append('Female')
    else:
        Gender.append('Others')

# %%
captitle = []
#form = 'Capsule'
for i in range(1,3):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop&formulation_filter=10830'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            captitle.append(j.text)
            
tabtitle = []
#form = 'Tablet'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop&formulation_filter=12424'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            tabtitle.append(j.text)

powtitle = []
#form = 'Powder'
for i in range(1,3):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop&formulation_filter=10812'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            powtitle.append(j.text)

'''geltitle = []
#form = 'Gel'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/multivitamins/c/18541?page_no={i}&sort=popularity&transaction_id=905462f5a8df1037c6b016a4ad9fb1f4&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Energy%20Boost:-1:905462f5a8df1037c6b016a4ad9fb1f4&eq=desktop&formulation_filter=10824'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            geltitle.append(j.text)
'''
liqtitle = []
#form = 'Liquid'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/hormonal-balance/c/19856?page_no={i}&sort=popularity&transaction_id=76bb7e1eeb1b278342be2ddfa111df57&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Hormonal%20Balance:-1:76bb7e1eeb1b278342be2ddfa111df57&eq=desktop&formulation_filter=10822'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            liqtitle.append(j.text)

# %%
Formulation = []

for i in title:
    if i in captitle:
        Formulation.append('Capsule')
    elif i in tabtitle:
        Formulation.append('Tablet')
    elif i in powtitle:
        Formulation.append('Powder')
    elif i in geltitle:
        Formulation.append('Gel')
    elif i in liqtitle:
        Formulation.append('Liquid')
    elif i in sttitle:
        Formulation.append('Stick')
    elif i in oiltitle:
        Formulation.append('Oil')
    else:
        Formulation.append('Others')

# %%
hbdata ={'Product_Title':title,
         'Original Price': ogprice,
         'Discounted Price':price,
         'Additional_Tags':feature,
         'Ratings':ratings,
         'Number_of_ratings':numratings,
         'Gender':Gender,
         'Category':category,
         'Formulation':Formulation}

# %%
hbdf = pd.DataFrame(hbdata)

# %%
hbdf
# Out:
#                                          Product_Title Original Price  \
# 0    OZiva Plant Based HerBalance for PCOS with Myo...       MRP:₹899
# 1    Kapiva Ayurveda Period Care Juice - 5 Ayurvedi...       MRP:₹599
# 2    Be Bodywise PCOS Balance Capsules, Balances Ho...       MRP:₹599
# 3    Power Gummies For That Time Of The Month - Per...       MRP:₹800
# 4    Chicnutrix Cysterhood Inositol - PCOS Ovarian ...      MRP:₹1035
# ..                                                 ...            ...
# 122  andMe Pcos Pcod Tea - Kashmiri Kahwa Flavour -...          ₹1320
# 123  Be Bodywise Pcos Support Kit For Menstrual Pai...       MRP:₹998
# 124  andMe Pcos Tea (Kashmiri Kahwa) + andMe Thyrod...          ₹1320
# 125  andMe Fertility Supplement Combo With Herbal P...          ₹2198
# 126                          Tea Trunk PMS Care Bundle       MRP:₹798
#
#     Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %% [markdown]
# # Stronger Bones

# %%
title = []
ogprice = []
price = []
feature = []
numratings = []


for i in range(1,11):
    url = f'https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.text)
    for Title in soup.find_all('div', class_='css-xrzmfa'):
        T = (Title.text)
        if T:
            title.append(T)
        else:
            title.append(np.nan)
##################################################################
    for i in soup.find_all('div', class_="css-1d0jf8e"):
        discount = i.find('span', class_="css-cjd9an")
        og = i.find('span', class_="css-17x46n5")
        nodisc = i.find('span', class_='css-111z9ua')
        if discount in i:#prods w/ discount
            ogprice.append(og.text)
        elif og:
            ogprice.append(nodisc.text)
        else:
            ogprice.append(np.nan)
##################################################################
    for i in soup.find_all('span', class_="css-111z9ua"):
        Price =(i.text)
        if Price:
            price.append(Price)
        else:
            price.append(np.nan)
##################################################################           
    for feat in soup.find_all('div',class_='css-wkluxr'):
        if feat:
            f= feat.find('ul',class_='css-ycjyr6')
            if f:
                li_elements = f.find_all('li', class_='custom-tag')
                
                if li_elements:
                    featured_present = any("FEATURED" in li.text for li in li_elements)
                    bestseller_present = any("BESTSELLER" in li.text for li in li_elements)

                    if featured_present and bestseller_present:
                        feature.append("FEATURED & BESTSELLER")
                    elif featured_present:
                        feature.append("FEATURED")
                    elif bestseller_present:
                        feature.append("BESTSELLER")
                    else:
                        feature.append(np.nan)
                else:
                    feature.append(np.nan)
            else:
                feature.append(np.nan)
        else:
            feature.append(np.nan)
##################################################################
    for prods in soup.find_all('div', class_="css-d5z3ro"):
        ratings = prods.find('div', class_="css-wskh5y")
        if ratings:
            numratings.append(ratings.text)
        else:
            numratings.append(np.nan)
##################################################################
ratings = []

for i in range(1,11):
    url = f'https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.content)
    for elements in soup.find_all('div', class_="css-d5z3ro"):#product
        reviews = elements.find('div', class_="css-wskh5y")#reviews
        if reviews:
            starElements = reviews.find_all('span',class_='star-wrap')
            count=0
            for star in starElements:
                res = star.find("path", {'fill-rule':'evenodd'})
                if res:
                    count=count+1
                else:
                    continue
            ratings.append(count)
        else:
            ratings.append(np.nan)
# Out:
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200
# page 8 status code:  200
# page 9 status code:  200
# page 10 status code:  200
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200
# page 8 status code:  200
# page 9 status code:  200
# page 10 status code:  200

# %%
category = []
cat = 'Stronger Bones'

for i in range(len(title)):
    category.append(cat)

# %%
uni=[]
unititle = []
gen = 'Unisex'
for i in range(1,10):
    url=f"https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop&gender_filter=10712"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            uni.append(gen)
            unititle.append(j.text)

# %%
femprod = []
femtitle = []
gen = 'Female'
for i in range(1,2):
    url=f"https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop&gender_filter=10711"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            femprod.append(gen)
            femtitle.append(j.text)

# %%
Gender = []

for i in title:
    if i in unititle:
        Gender.append('Unisex')
    elif i in femtitle:
        Gender.append('Female')
    else:
        Gender.append('Others')

# %%
captitle = []
#form = 'Capsule'
for i in range(1,6):
    url =f'https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop&formulation_filter=10830'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            captitle.append(j.text)
            
tabtitle = []
#form = 'Tablet'
for i in range(1,5):
    url =f'https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop&formulation_filter=12424'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            tabtitle.append(j.text)

powtitle = []
#form = 'Powder'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop&formulation_filter=10812'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            powtitle.append(j.text)


liqtitle = []
#form = 'Liquid'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/calcium-vitamin-d/c/18544?page_no={i}&sort=popularity&transaction_id=e017e431e704a07a015a53752be4c134&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Stronger%20Bones:-1:e017e431e704a07a015a53752be4c134&eq=desktop&formulation_filter=10822'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            liqtitle.append(j.text)

# %%
Formulation = []

for i in title:
    if i in captitle:
        Formulation.append('Capsule')
    elif i in tabtitle:
        Formulation.append('Tablet')
    elif i in powtitle:
        Formulation.append('Powder')
    elif i in geltitle:
        Formulation.append('Gel')
    elif i in liqtitle:
        Formulation.append('Liquid')
    else:
        Formulation.append('Others')

# %%
sbdata ={'Product_Title':title,
         'Original Price': ogprice,
         'Discounted Price':price,
         'Additional_Tags':feature,
         'Ratings':ratings,
         'Number_of_ratings':numratings,
         'Gender':Gender,
         'Category':category,
         'Formulation':Formulation}

# %%
sbdf = pd.DataFrame(sbdata)

# %%
sbdf
# Out:
#                                          Product_Title Original Price  \
# 0    Wellbeing Nutrition Melts Natural Vitamin D3 +...       MRP:₹649
# 1    HealthKart Hk Vitals Vitamin D3 (2000 IU) Caps...       MRP:₹849
# 2    OZiva Bettr.CalD3+, Plant-Based Calcium & Vita...       MRP:₹699
# 3    Mars by GHC Vitamin D3 Tablets For Bone Health...       MRP:₹599
# 4    Carbamide Forte Calcium with Magnesium- Zinc- ...       MRP:₹920
# ..                                                 ...            ...
# 192  HealthVit Calvitan-kid - Kid's Calcium 150mg V...           ₹340
# 193           Healthvit Vitamin D3 1000IU (30 Tablets)           ₹240
# 194    HealthVit Vitamin D3 1000IU Tablets (Pack Of 2)           ₹600
# 195  Healthvit Calvitan-600 Calcium Carbonate 600mg...           ₹300
# 196  Healthvit Calvitan-D Calcium, Vitamin D & Chon...           ₹700
#
#     Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %% [markdown]
# # Healthy Heart

# %%
title = []
ogprice = []
price = []
feature = []
numratings = []


for i in range(1,10):
    url = f'https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.text)
    for Title in soup.find_all('div', class_='css-xrzmfa'):
        T = (Title.text)
        if T:
            title.append(T)
        else:
            title.append(np.nan)
##################################################################
    for i in soup.find_all('div', class_="css-1d0jf8e"):
        discount = i.find('span', class_="css-cjd9an")
        og = i.find('span', class_="css-17x46n5")
        nodisc = i.find('span', class_='css-111z9ua')
        if discount in i:#prods w/ discount
            ogprice.append(og.text)
        elif og:
            ogprice.append(nodisc.text)
        else:
            ogprice.append(np.nan)
##################################################################
    for i in soup.find_all('span', class_="css-111z9ua"):
        Price =(i.text)
        if Price:
            price.append(Price)
        else:
            price.append(np.nan)
##################################################################           
    for feat in soup.find_all('div',class_='css-wkluxr'):
        if feat:
            f= feat.find('ul',class_='css-ycjyr6')
            if f:
                li_elements = f.find_all('li', class_='custom-tag')
                
                if li_elements:
                    featured_present = any("FEATURED" in li.text for li in li_elements)
                    bestseller_present = any("BESTSELLER" in li.text for li in li_elements)

                    if featured_present and bestseller_present:
                        feature.append("FEATURED & BESTSELLER")
                    elif featured_present:
                        feature.append("FEATURED")
                    elif bestseller_present:
                        feature.append("BESTSELLER")
                    else:
                        feature.append(np.nan)
                else:
                    feature.append(np.nan)
            else:
                feature.append(np.nan)
        else:
            feature.append(np.nan)
##################################################################
    for prods in soup.find_all('div', class_="css-d5z3ro"):
        ratings = prods.find('div', class_="css-wskh5y")
        if ratings:
            numratings.append(ratings.text)
        else:
            numratings.append(np.nan)
##################################################################
ratings = []

for i in range(1,10):
    url = f'https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop'
    page = requests.get(url)
    soup = BeautifulSoup(page.content)
    for elements in soup.find_all('div', class_="css-d5z3ro"):#product
        reviews = elements.find('div', class_="css-wskh5y")#reviews
        if reviews:
            starElements = reviews.find_all('span',class_='star-wrap')
            count=0
            for star in starElements:
                res = star.find("path", {'fill-rule':'evenodd'})
                if res:
                    count=count+1
                else:
                    continue
            ratings.append(count)
        else:
            ratings.append(np.nan)
# Out:
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200
# page 8 status code:  200
# page 9 status code:  200

# %%
category = []
cat = 'Healthy Heart'

for i in range(len(title)):
    category.append(cat)

# %%
uni=[]
unititle = []
gen = 'Unisex'
for i in range(1,9):
    url=f"https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&gender_filter=10712"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            uni.append(gen)
            unititle.append(j.text)

# %%
femprod = []
femtitle = []
gen = 'Female'
for i in range(1,2):
    url =f"https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&gender_filter=10711"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            femprod.append(gen)
            femtitle.append(j.text)

# %%
maleprod = []
maletitle = []
gen = 'Male'
for i in range(1,2):
    url=f"https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&gender_filter=10710"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            maleprod.append(gen)
            maletitle.append(j.text)

# %%
Gender = []

for i in title:
    if i in unititle:
        Gender.append('Unisex')
    elif i in femtitle:
        Gender.append('Female')
    elif i in maletitle:
        Gender.append('Male')
    else:
        Gender.append('Others')

# %%
captitle = []
#form = 'Capsule'
for i in range(1,8):
    url =f'https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&formulation_filter=10830'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            captitle.append(j.text)
            
tabtitle = []
#form = 'Tablet'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&formulation_filter=12424'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            tabtitle.append(j.text)

powtitle = []
#form = 'Powder'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&formulation_filter=10812'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            powtitle.append(j.text)



oiltitle = []
#form = 'Oil'
for i in range(1,2):
    url = f'https://www.nykaa.com/wellness/health-supplements/omega-3-fish-oil/c/2020?page_no={i}&sort=popularity&transaction_id=b563a6e74f35201a507951ac903951cb&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Healthy%20Heart:-1:b563a6e74f35201a507951ac903951cb&eq=desktop&formulation_filter=10817'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            oiltitle.append(j.text)

# %%
Formulation = []

for i in title:
    if i in captitle:
        Formulation.append('Capsule')
    elif i in tabtitle:
        Formulation.append('Tablet')
    elif i in powtitle:
        Formulation.append('Powder')
    elif i in geltitle:
        Formulation.append('Gel')
    elif i in liqtitle:
        Formulation.append('Liquid')
    elif i in sttitle:
        Formulation.append('Stick')
    elif i in oiltitle:
        Formulation.append('Oil')
    else:
        Formulation.append('Others')

# %%
hhdata ={'Product_Title':title,
         'Original Price': ogprice,
         'Discounted Price':price,
         'Additional_Tags':feature,
         'Ratings':ratings,
         'Number_of_ratings':numratings,
         'Gender':Gender,
         'Category':category,
         'Formulation':Formulation}

# %%
hhdf = pd.DataFrame(hhdata)

# %%
hhdf
# Out:
#                                          Product_Title Original Price  \
# 0    HealthKart Hk Vitals Fish Oil, 1000 Mg Omega 3...      MRP:₹1000
# 1    GNC Triple Strength Fish Oil Omega 3 Capsules ...      MRP:₹1599
# 2    MOUNTAINOR Deep Sea Omega 3 Fish Oil 2500MG of...      MRP:₹1199
# 3    Neuherbs Deep Sea Omega 3 Fish Oil 2500mg Caps...      MRP:₹1099
# 4    Wellbeing Nutrition Slow - Extra Virgin Omega-...      MRP:₹1899
# ..                                                 ...            ...
# 169  MOUNTAINOR Omega 3 (1000mg) Fish Oil Softgels ...      MRP:₹1298
# 170  MOUNTAINOR Multivitamins Capsules + Omega 3 (1...      MRP:₹1348
# 171       Healthvit Flaxseed Oil - 60 Softgel Capsules           ₹450
# 172  HealthVit Omega-3 Fish Oil Double Strength 100...           ₹800
# 173  Healthvit Omega 3 Fatty Acids Oil - 60 Softgel...           ₹600
#
#     Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %% [markdown]
# # Restful Sleep

# %%
title = []
ogprice = []
price = []
feature = []
numratings = []


for i in range(1,8):
    url = f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.text)
    for Title in soup.find_all('div', class_='css-xrzmfa'):
        T = (Title.text)
        if T:
            title.append(T)
        else:
            title.append(np.nan)
##################################################################
    for i in soup.find_all('div', class_="css-1d0jf8e"):
        discount = i.find('span', class_="css-cjd9an")
        og = i.find('span', class_="css-17x46n5")
        nodisc = i.find('span', class_='css-111z9ua')
        if discount in i:#prods w/ discount
            ogprice.append(og.text)
        elif og:
            ogprice.append(nodisc.text)
        else:
            ogprice.append(np.nan)
##################################################################
    for i in soup.find_all('span', class_="css-111z9ua"):
        Price =(i.text)
        if Price:
            price.append(Price)
        else:
            price.append(np.nan)
##################################################################           
    for feat in soup.find_all('div',class_='css-wkluxr'):
        if feat:
            f= feat.find('ul',class_='css-ycjyr6')
            if f:
                li_elements = f.find_all('li', class_='custom-tag')
                
                if li_elements:
                    featured_present = any("FEATURED" in li.text for li in li_elements)
                    bestseller_present = any("BESTSELLER" in li.text for li in li_elements)

                    if featured_present and bestseller_present:
                        feature.append("FEATURED & BESTSELLER")
                    elif featured_present:
                        feature.append("FEATURED")
                    elif bestseller_present:
                        feature.append("BESTSELLER")
                    else:
                        feature.append(np.nan)
                else:
                    feature.append(np.nan)
            else:
                feature.append(np.nan)
        else:
            feature.append(np.nan)
##################################################################
    for prods in soup.find_all('div', class_="css-d5z3ro"):
        ratings = prods.find('div', class_="css-wskh5y")
        if ratings:
            numratings.append(ratings.text)
        else:
            numratings.append(np.nan)
##################################################################
ratings = []

for i in range(1,8):
    url = f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop'
    page = requests.get(url)
    print(f'page {i} status code: ',page.status_code)
    soup = BeautifulSoup(page.content)
    for elements in soup.find_all('div', class_="css-d5z3ro"):#product
        reviews = elements.find('div', class_="css-wskh5y")#reviews
        if reviews:
            starElements = reviews.find_all('span',class_='star-wrap')
            count=0
            for star in starElements:
                res = star.find("path", {'fill-rule':'evenodd'})
                if res:
                    count=count+1
                else:
                    continue
            ratings.append(count)
        else:
            ratings.append(np.nan)
# Out:
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200
# page 1 status code:  200
# page 2 status code:  200
# page 3 status code:  200
# page 4 status code:  200
# page 5 status code:  200
# page 6 status code:  200
# page 7 status code:  200

# %%
category = []
cat = 'Restful Sleep'

for i in range(len(title)):
    category.append(cat)

# %%
femprod = []
femtitle = []
gen = 'Female'
for i in range(1,2):
    url=f"https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&gender_filter=10711"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            femprod.append(gen)
            femtitle.append(j.text)

# %%
maleprod = []
maletitle = []
gen = 'Male'
for i in range(1,2):
    url=f"https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&gender_filter=10710"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            maleprod.append(gen)
            maletitle.append(j.text)

# %%
uni=[]
unititle = []
gen = 'Unisex'
for i in range(1,7):
    url=f"https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&gender_filter=10712"
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            uni.append(gen)
            unititle.append(j.text)

# %%
Gender = []
for i in title:
    if i in unititle:
        Gender.append('Unisex')
    elif i in femtitle:
        Gender.append('Female')
    elif i in maletitle:
        Gender.append('Male')
    else:
        Gender.append('Others')

# %%
captitle = []
#form = 'Capsule'
for i in range(1,4):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10830'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            captitle.append(j.text)
            
tabtitle = []
#form = 'Tablet'
for i in range(1,3):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=12424'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            tabtitle.append(j.text)

powtitle = []
#form = 'Powder'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10812'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            powtitle.append(j.text)

rolltitle = []
#form = 'Roll-on'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10810'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            rolltitle.append(j.text)

liqtitle = []
#form = 'Liquid'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10822'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            liqtitle.append(j.text)
            
spraytitle = []
#form = 'Spray'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10805'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            spraytitle.append(j.text)
            

masktitle = []
#form = 'Mask'
for i in range(1,2):
    url =f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10820'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            masktitle.append(j.text)
            

oiltitle = []
#form = 'Oil'
for i in range(1,2):
    url = f'https://www.nykaa.com/wellness/shop-by-concern/calm-sleep/c/19857?page_no={i}&sort=popularity&transaction_id=5b27ef726d5bd8939ac8ccb0ad2b98de&intcmp=nykaa:plp:desktop-category-listing:18540:shop-by-category:SLIDING_WIDGET_V2:1:Restful%20Sleep:-1:5b27ef726d5bd8939ac8ccb0ad2b98de&eq=desktop&formulation_filter=10817'
    page = requests.get(url)
    soup =BeautifulSoup(page.text)
    for j in soup.find_all('div', class_='css-xrzmfa'):
        if j.text in title:
            oiltitle.append(j.text)

# %%
Formulation = []

for i in title:
    if i in captitle:
        Formulation.append('Capsule')
    elif i in tabtitle:
        Formulation.append('Tablet')
    elif i in powtitle:
        Formulation.append('Powder')
    elif i in geltitle:
        Formulation.append('Gel')
    elif i in liqtitle:
        Formulation.append('Liquid')
    elif i in sttitle:
        Formulation.append('Stick')
    elif i in oiltitle:
        Formulation.append('Oil')
    else:
        Formulation.append('Others')

# %%
rsdata ={'Product_Title':title,
         'Original Price': ogprice,
         'Discounted Price':price,
         'Additional_Tags':feature,
         'Ratings':ratings,
         'Number_of_ratings':numratings,
         'Gender':Gender,
         'Category':category,
         'Formulation':Formulation}

# %%
rsdf = pd.DataFrame(rsdata)

# %%
rsdf
# Out:
#                                          Product_Title Original Price  \
# 0       What's Up Wellness Sleep Gummy Muscle Recovery       MRP:₹899
# 1                 Power Gummies Blessful Sleep Gummies           ₹200
# 2    GNC Melatonin 3 Mg - Supports Restful Sleep - ...       MRP:₹599
# 3    Carbamide Forte Sleeping Pills Melatonin 10mg ...       MRP:₹920
# 4    Wellbeing Nutrition Melts Restful Sleep, Melat...       MRP:₹649
# ..                                                 ...            ...
# 125  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...           ₹500
# 126  Healthvit Sleepneed Melatonin 10 mg Advanced S...           ₹700
# 127                       HealthVit Ashwagandha Powder           ₹155
# 128                       HealthVit Ashwagandha Powder           ₹155
# 129     Healthvit Ashwagandha Powder 250mg (Pack of 2)           ₹400
#
#     Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %%
compiled = pd.concat([df, ibdf,hbdf,sbdf,hhdf,rsdf], axis=0, ignore_index=True)

# %%
compiled
# Out:
#                                           Product_Title Original Price  \
# 0     Wellbeing Nutrition Daily Greens Wholefood Mul...      MRP:₹1180
# 1     HealthKart HK Vitals Multivitamin for Women, B...       MRP:₹529
# 2          GNC Women's One Daily Multivitamin For Women      MRP:₹1449
# 3     Oziva Daily Women's Multivitamin Tablets For E...       MRP:₹499
# 4     Carbamide Forte Novosules Woman+ Multivitamin ...       MRP:₹770
# ...                                                 ...            ...
# 1299  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...           ₹500
# 1300  Healthvit Sleepneed Melatonin 10 mg Advanced S...           ₹700
# 1301                       HealthVit Ashwagandha Powder           ₹155
# 1302                       HealthVit Ashwagandha Powder           ₹155
# 1303     Healthvit Ashwagandha Powder 250mg (Pack of 2)           ₹400
#
#      Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %%
compiled.duplicated().sum()
# Out:
# 2

# %%
compiled.drop_duplicates()
# Out:
#                                           Product_Title Original Price  \
# 0     Wellbeing Nutrition Daily Greens Wholefood Mul...      MRP:₹1180
# 1     HealthKart HK Vitals Multivitamin for Women, B...       MRP:₹529
# 2          GNC Women's One Daily Multivitamin For Women      MRP:₹1449
# 3     Oziva Daily Women's Multivitamin Tablets For E...       MRP:₹499
# 4     Carbamide Forte Novosules Woman+ Multivitamin ...       MRP:₹770
# ...                                                 ...            ...
# 1299  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...           ₹500
# 1300  Healthvit Sleepneed Melatonin 10 mg Advanced S...           ₹700
# 1301                       HealthVit Ashwagandha Powder           ₹155
# 1302                       HealthVit Ashwagandha Powder           ₹155
# 1303     Healthvit Ashwagandha Powder 250mg (Pack of 2)           ₹400
#
#      Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# ...

# %%
compiled.to_csv("NykaaHealthSupp.csv")
