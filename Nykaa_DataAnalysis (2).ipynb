# %% [markdown]
# # Nyka_Health_Supplements_Dataset

# %% [markdown]
# ## Introduction

# %% [markdown]
# In contemporary society, the prevalence of unhealthy dietary choices has reached alarming proportions, The COVID-19 pandemic has made things worse by disrupting our normal routines. This has shown us how crucial it is to stay healthy and find good ways to deal with the downsides of sedentary lifestyles and poor nutritional habits.The dataset we are working with contains a range of features related to health care products, and by analyzing this data, we aim to create a valuable tool for individuals.

# %% [markdown]
# * Our primary goal is to develop a diagnostic model that can accurately analysis between different categories such as Immunity Booster, Hormonal Balance, Stronger Bones, Restful sleep,Energy Boosters using the provided attributes, Product Titles, Ratings, Bestsellers,Gender,Formulations,Original Price, Discounted Price.

# %% [markdown]
# * Attribute Information

# %% [markdown]
# 1. Product Title
# 2. Original Price.
# 3. Discounted Price.
# 4. Additional_Tags.
# 5. Ratings.
# 6. Gender.
# 7. Category.
# 8. Formulation

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Nutritional Deficiency, Unhealthy habits, and the effects of post-COVID-19 vaccines are the major concerns that every individual suffers from. A comprehensive understanding of these common responses is necessary to develop targeted interventions and support systems that enhance the overall immune system and public health resilience

# %% [markdown]
# ## Nyka data cleaning and data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv(r"C:\Users\anaji\Sowjanya\Project  Nyka\NykaaHealthSupp.csv")

# %%
df
# Out:
#       Unnamed: 0                                      Product_Title  \
# 0              0       GNC Women's One Daily Multivitamin For Women
# 1              1  HealthKart Hk Vitals Multivitamin For Women, B...
# 2              2  Oziva Daily Women's Multivitamin Tablets For E...
# 3              3           Neuherbs Hair Skin & Vitamins Supplement
# 4              4  Swisse Women's Multivitamin for Energy, Stamin...
# ...          ...                                                ...
# 1254        1254  Healthvit Sleepneed Melatonin 5 mg Advanced Sl...
# 1255        1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...
# 1256        1256                       HealthVit Ashwagandha Powder
# 1257        1257                       HealthVit Ashwagandha Powder
# 1258        1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)
#
#      Original Price Discounted Price        Additional_Tags  Ratings  \
# 0         MRP:₹1449             ₹899  FEATURED & BESTSELLER      5.0
# 1          MRP:₹529             ₹399  FEATURED & BESTSELLER      4.0
# 2          MRP:₹499             ₹299  FEATURED & BESTSELLER      4.0
# 3          MRP:₹999             ₹699  FEATURED & BESTSELLER      4.0
# 4         MRP:₹2349            ₹1715  FEATURED & BESTSELLER      4.0
# ...             ...              ...                    ...      ...
# 1254           ₹600             ₹600                    NaN      NaN
# 1255           ₹500             ₹500                    NaN      1.0
# 1256           ₹155             ₹155                    NaN      5.0
# 1257           ₹155             ₹155                    NaN      4.0
# 1258           ₹400             ₹400                    NaN      4.0
#
#      Number_of_ratings   Gender         Category Formulation
# 0               ( 68 )   Female  Energy-boosters      Tablet
# 1              ( 202 )   Unisex  Energy-boosters      Tablet
# 2               ( 96 )   Female  Energy-boosters      Tablet
# 3              ( 148 )  Unknown  Energy-boosters     Unknown
# 4               ( 28 )   Female  Energy-boosters     Unknown
# ...                ...      ...              ...         ...
# 1254               NaN   Unisex    Restful Sleep      Tablet
# 1255             ( 1 )   Unisex    Restful Sleep      Tablet
# 1256            ( 12 )   Unisex    Restful Sleep      Powder
# 1257             ( 1 )   Unisex    Restful Sleep      Powder
# 1258             ( 1 )   Unisex    Restful Sleep     Unknown
#
# [1259 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Product_Title', 'Original Price', 'Discounted Price',
#        'Additional_Tags', 'Ratings', 'Number_of_ratings', 'Gender', 'Category',
#        'Formulation'],
#       dtype='object')

# %%
df = df.drop(columns='Unnamed: 0')

# %%
df = df.drop(columns='Number_of_ratings')

# %%
df
# Out:
#                                           Product_Title Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women      MRP:₹1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...       MRP:₹529
# 2     Oziva Daily Women's Multivitamin Tablets For E...       MRP:₹499
# 3              Neuherbs Hair Skin & Vitamins Supplement       MRP:₹999
# 4     Swisse Women's Multivitamin for Energy, Stamin...      MRP:₹2349
# ...                                                 ...            ...
# 1254  Healthvit Sleepneed Melatonin 5 mg Advanced Sl...           ₹600
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...           ₹500
# 1256                       HealthVit Ashwagandha Powder           ₹155
# 1257                       HealthVit Ashwagandha Powder           ₹155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)           ₹400
#
#      Discounted Price        Additional_Tags  Ratings   Gender  \
# 0                ₹899  FEATURED & BESTSELLER      5.0   Female
# 1                ₹399  FEATURED & BESTSELLER      4.0   Unisex
# 2                ₹299  FEATURED & BESTSELLER      4.0   Female
# 3                ₹699  FEATURED & BESTSELLER      4.0  Unknown
# 4               ₹1715  FEATURED & BESTSELLER      4.0   Female
# ...               ...                    ...      ...      ...
# 1254             ₹600                    NaN      NaN   Unisex
# 1255             ₹500                    NaN      1.0   Unisex
# 1256             ₹155                    NaN      5.0   Unisex
# 1257             ₹155                    NaN      4.0   Unisex
# 1258             ₹400                    NaN      4.0   Unisex
#
#              Category Formulation
# 0     Energy-boosters      Tablet
# 1     Energy-boosters      Tablet
# 2     Energy-boosters      Tablet
# 3     Energy-boosters     Unknown
# 4     Energy-boosters     Unknown
# ...               ...         ...
# 1254    Restful Sleep      Tablet
# 1255    Restful Sleep      Tablet
# 1256    Restful Sleep      Powder
# 1257    Restful Sleep      Powder
# 1258    Restful Sleep     Unknown
#
# [1259 rows x 8 columns]

# %% [markdown]
# # Structural errors

# %%
df['Original Price']=df['Original Price'].replace("['MRP:','\u20B9']","",regex=True)

# %%
df['Original Price']
# Out:
# 0       1449
# 1        529
# 2        499
# 3        999
# 4       2349
#         ...
# 1254     600
# 1255     500
# 1256     155
# 1257     155
# 1258     400
# Name: Original Price, Length: 1259, dtype: object

# %%
df['Discounted Price']=df['Discounted Price'].replace("['\u20B9']","",regex=True)

# %%
df['Discounted Price']
# Out:
# 0        899
# 1        399
# 2        299
# 3        699
# 4       1715
#         ...
# 1254     600
# 1255     500
# 1256     155
# 1257     155
# 1258     400
# Name: Discounted Price, Length: 1259, dtype: object

# %% [markdown]
# # Missing values

# %%
df.isna().sum()
# Out:
# Product_Title          0
# Original Price         0
# Discounted Price       0
# Additional_Tags     1208
# Ratings              405
# Gender                 0
# Category               0
# Formulation            0
# dtype: int64

# %%
df
# Out:
#                                           Product_Title Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women           1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...            529
# 2     Oziva Daily Women's Multivitamin Tablets For E...            499
# 3              Neuherbs Hair Skin & Vitamins Supplement            999
# 4     Swisse Women's Multivitamin for Energy, Stamin...           2349
# ...                                                 ...            ...
# 1254  Healthvit Sleepneed Melatonin 5 mg Advanced Sl...            600
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...            500
# 1256                       HealthVit Ashwagandha Powder            155
# 1257                       HealthVit Ashwagandha Powder            155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)            400
#
#      Discounted Price        Additional_Tags  Ratings   Gender  \
# 0                 899  FEATURED & BESTSELLER      5.0   Female
# 1                 399  FEATURED & BESTSELLER      4.0   Unisex
# 2                 299  FEATURED & BESTSELLER      4.0   Female
# 3                 699  FEATURED & BESTSELLER      4.0  Unknown
# 4                1715  FEATURED & BESTSELLER      4.0   Female
# ...               ...                    ...      ...      ...
# 1254              600                    NaN      NaN   Unisex
# 1255              500                    NaN      1.0   Unisex
# 1256              155                    NaN      5.0   Unisex
# 1257              155                    NaN      4.0   Unisex
# 1258              400                    NaN      4.0   Unisex
#
#              Category Formulation
# 0     Energy-boosters      Tablet
# 1     Energy-boosters      Tablet
# 2     Energy-boosters      Tablet
# 3     Energy-boosters     Unknown
# 4     Energy-boosters     Unknown
# ...               ...         ...
# 1254    Restful Sleep      Tablet
# 1255    Restful Sleep      Tablet
# 1256    Restful Sleep      Powder
# 1257    Restful Sleep      Powder
# 1258    Restful Sleep     Unknown
#
# [1259 rows x 8 columns]

# %%
df['Additional_Tags'] = df['Additional_Tags'].fillna('Rising Products')

# %%
df
# Out:
#                                           Product_Title Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women           1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...            529
# 2     Oziva Daily Women's Multivitamin Tablets For E...            499
# 3              Neuherbs Hair Skin & Vitamins Supplement            999
# 4     Swisse Women's Multivitamin for Energy, Stamin...           2349
# ...                                                 ...            ...
# 1254  Healthvit Sleepneed Melatonin 5 mg Advanced Sl...            600
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...            500
# 1256                       HealthVit Ashwagandha Powder            155
# 1257                       HealthVit Ashwagandha Powder            155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)            400
#
#      Discounted Price        Additional_Tags  Ratings   Gender  \
# 0                 899  FEATURED & BESTSELLER      5.0   Female
# 1                 399  FEATURED & BESTSELLER      4.0   Unisex
# 2                 299  FEATURED & BESTSELLER      4.0   Female
# 3                 699  FEATURED & BESTSELLER      4.0  Unknown
# 4                1715  FEATURED & BESTSELLER      4.0   Female
# ...               ...                    ...      ...      ...
# 1254              600        Rising Products      NaN   Unisex
# 1255              500        Rising Products      1.0   Unisex
# 1256              155        Rising Products      5.0   Unisex
# 1257              155        Rising Products      4.0   Unisex
# 1258              400        Rising Products      4.0   Unisex
#
#              Category Formulation
# 0     Energy-boosters      Tablet
# 1     Energy-boosters      Tablet
# 2     Energy-boosters      Tablet
# 3     Energy-boosters     Unknown
# 4     Energy-boosters     Unknown
# ...               ...         ...
# 1254    Restful Sleep      Tablet
# 1255    Restful Sleep      Tablet
# 1256    Restful Sleep      Powder
# 1257    Restful Sleep      Powder
# 1258    Restful Sleep     Unknown
#
# [1259 rows x 8 columns]

# %%
df.dropna(axis=0, inplace=True)

# %%
df
# Out:
#                                           Product_Title Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women           1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...            529
# 2     Oziva Daily Women's Multivitamin Tablets For E...            499
# 3              Neuherbs Hair Skin & Vitamins Supplement            999
# 4     Swisse Women's Multivitamin for Energy, Stamin...           2349
# ...                                                 ...            ...
# 1253  Healthvit Sleepneed Melatonin 10 mg Advanced S...            700
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...            500
# 1256                       HealthVit Ashwagandha Powder            155
# 1257                       HealthVit Ashwagandha Powder            155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)            400
#
#      Discounted Price        Additional_Tags  Ratings   Gender  \
# 0                 899  FEATURED & BESTSELLER      5.0   Female
# 1                 399  FEATURED & BESTSELLER      4.0   Unisex
# 2                 299  FEATURED & BESTSELLER      4.0   Female
# 3                 699  FEATURED & BESTSELLER      4.0  Unknown
# 4                1715  FEATURED & BESTSELLER      4.0   Female
# ...               ...                    ...      ...      ...
# 1253              700        Rising Products      4.0   Unisex
# 1255              500        Rising Products      1.0   Unisex
# 1256              155        Rising Products      5.0   Unisex
# 1257              155        Rising Products      4.0   Unisex
# 1258              400        Rising Products      4.0   Unisex
#
#              Category Formulation
# 0     Energy-boosters      Tablet
# 1     Energy-boosters      Tablet
# 2     Energy-boosters      Tablet
# 3     Energy-boosters     Unknown
# 4     Energy-boosters     Unknown
# ...               ...         ...
# 1253    Restful Sleep      Tablet
# 1255    Restful Sleep      Tablet
# 1256    Restful Sleep      Powder
# 1257    Restful Sleep      Powder
# 1258    Restful Sleep     Unknown
#
# [854 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Product_Title       0
# Original Price      0
# Discounted Price    0
# Additional_Tags     0
# Ratings             0
# Gender              0
# Category            0
# Formulation         0
# dtype: int64

# %% [markdown]
# # Type casting

# %%
df.dtypes
# Out:
# Product_Title        object
# Original Price       object
# Discounted Price     object
# Additional_Tags      object
# Ratings             float64
# Gender               object
# Category             object
# Formulation          object
# dtype: object

# %%
df[['Original Price',"Discounted Price",'Ratings']]=df[['Original Price',"Discounted Price",'Ratings']].astype('int64')

# %%
df.dtypes
# Out:
# Product_Title       object
# Original Price       int64
# Discounted Price     int64
# Additional_Tags     object
# Ratings              int64
# Gender              object
# Category            object
# Formulation         object
# dtype: object

# %%
df
# Out:
#                                           Product_Title  Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women            1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...             529
# 2     Oziva Daily Women's Multivitamin Tablets For E...             499
# 3              Neuherbs Hair Skin & Vitamins Supplement             999
# 4     Swisse Women's Multivitamin for Energy, Stamin...            2349
# ...                                                 ...             ...
# 1253  Healthvit Sleepneed Melatonin 10 mg Advanced S...             700
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...             500
# 1256                       HealthVit Ashwagandha Powder             155
# 1257                       HealthVit Ashwagandha Powder             155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)             400
#
#       Discounted Price        Additional_Tags  Ratings   Gender  \
# 0                  899  FEATURED & BESTSELLER        5   Female
# 1                  399  FEATURED & BESTSELLER        4   Unisex
# 2                  299  FEATURED & BESTSELLER        4   Female
# 3                  699  FEATURED & BESTSELLER        4  Unknown
# 4                 1715  FEATURED & BESTSELLER        4   Female
# ...                ...                    ...      ...      ...
# 1253               700        Rising Products        4   Unisex
# 1255               500        Rising Products        1   Unisex
# 1256               155        Rising Products        5   Unisex
# 1257               155        Rising Products        4   Unisex
# 1258               400        Rising Products        4   Unisex
#
#              Category Formulation
# 0     Energy-boosters      Tablet
# 1     Energy-boosters      Tablet
# 2     Energy-boosters      Tablet
# 3     Energy-boosters     Unknown
# 4     Energy-boosters     Unknown
# ...               ...         ...
# 1253    Restful Sleep      Tablet
# 1255    Restful Sleep      Tablet
# 1256    Restful Sleep      Powder
# 1257    Restful Sleep      Powder
# 1258    Restful Sleep     Unknown
#
# [854 rows x 8 columns]

# %%
df
# Out:
#                                           Product_Title  Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women            1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...             529
# 2     Oziva Daily Women's Multivitamin Tablets For E...             499
# 3              Neuherbs Hair Skin & Vitamins Supplement             999
# 4     Swisse Women's Multivitamin for Energy, Stamin...            2349
# ...                                                 ...             ...
# 1253  Healthvit Sleepneed Melatonin 10 mg Advanced S...             700
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...             500
# 1256                       HealthVit Ashwagandha Powder             155
# 1257                       HealthVit Ashwagandha Powder             155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)             400
#
#       Discounted Price        Additional_Tags  Ratings   Gender  \
# 0                  899  FEATURED & BESTSELLER        5   Female
# 1                  399  FEATURED & BESTSELLER        4   Unisex
# 2                  299  FEATURED & BESTSELLER        4   Female
# 3                  699  FEATURED & BESTSELLER        4  Unknown
# 4                 1715  FEATURED & BESTSELLER        4   Female
# ...                ...                    ...      ...      ...
# 1253               700        Rising Products        4   Unisex
# 1255               500        Rising Products        1   Unisex
# 1256               155        Rising Products        5   Unisex
# 1257               155        Rising Products        4   Unisex
# 1258               400        Rising Products        4   Unisex
#
#              Category Formulation
# 0     Energy-boosters      Tablet
# 1     Energy-boosters      Tablet
# 2     Energy-boosters      Tablet
# 3     Energy-boosters     Unknown
# 4     Energy-boosters     Unknown
# ...               ...         ...
# 1253    Restful Sleep      Tablet
# 1255    Restful Sleep      Tablet
# 1256    Restful Sleep      Powder
# 1257    Restful Sleep      Powder
# 1258    Restful Sleep     Unknown
#
# [854 rows x 8 columns]

# %%
df.to_csv("NykaaHealthSuppclean.csv")

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
sns.distplot(df['Discounted Price'], color='orange')
# Out:
# C:\Users\anaji\AppData\Local\Temp\ipykernel_18212\3371525591.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Discounted Price'], color='orange')
# <Axes: xlabel='Discounted Price', ylabel='Density'>

# %% [markdown]
# Insights:
#
#     * most of the products' price is below 1500

# %%
(df['Category'].value_counts()/len(df['Category'])).plot(kind='pie',
                                                                          legend=True,
                                                                          autopct = '%2.2f%%',
                                                                          figsize=(8,10),
                                                                          ylabel = 'Percentage')
# Out:
# <Axes: ylabel='Percentage'>

# %% [markdown]
# Insights:
#     * The pie chart illustrates the distribution of each category products
#     * Energy-boosters products dominate the budget, accounting for 32.63% of the total available products
#     * Followed by Immunity boosters which contribute 18.01%
#     * Notably, restful sleep products are relatively low at 9.24%
#     * In the pie chart representation, both 'Stronger Bones' and 'Healthy Heart' categories share an equal percentage of products on the site, reflecting a balanced distribution and highlighting the importance placed on both bone health and cardiovascular well-being
#     --Energy boosters and immunity boosters together makeup 50% of the data

# %% [markdown]
# ### Bivariate Analysis

# %%
df.corr(numeric_only=True)
# Out:
#                   Original Price  Discounted Price   Ratings
# Original Price          1.000000          0.925383  0.018921
# Discounted Price        0.925383          1.000000 -0.020639
# Ratings                 0.018921         -0.020639  1.000000

# %%
df.plot('Original Price', 'Discounted Price', kind='scatter')
# Out:
# <Axes: xlabel='Original Price', ylabel='Discounted Price'>

# %%
Insights:
    *The scatter plot depicts the relationship between Original price(x-axis) and Discounted Price on y-axis
    *Evidently, there is a positive correlation between original price and discounted price
    *From the correlation matrix, the correlation coefficient between original price and discounted price is strong and almost perfectly correlated(0.93)
    *There are few data points that significatly deviate from the overall pattern(4-5outliers)

# %%
fig, ax = plt.subplots()
sns.countplot(data = df, x='Ratings', hue='Gender')
plt.figure(figsize=(8,6))
plt.show()

# %%
Insights:
    *The bar graph provides an overview of how ratings are distributed across different gender categories
    *Ratings are measured on a scale from 1 to 5.
    *The bars for unisex generally appear higher, indicating a tendency to give higher ratings.
    *Males, on the other hand, exhibit a more varied distribution, with less number of ratings. And t
    *Despite the male category having fewer ratings, it is noteworthy that there are no instances where customers gave 1 or 2-star ratings

# %%
df
# Out:
#                                           Product_Title  Original Price  \
# 0          GNC Women's One Daily Multivitamin For Women            1449
# 1     HealthKart Hk Vitals Multivitamin For Women, B...             529
# 2     Oziva Daily Women's Multivitamin Tablets For E...             499
# 3              Neuherbs Hair Skin & Vitamins Supplement             999
# 4     Swisse Women's Multivitamin for Energy, Stamin...            2349
# ...                                                 ...             ...
# 1253  Healthvit Sleepneed Melatonin 10 mg Advanced S...             700
# 1255  Healthvit Sleepneed Melatonin 3 mg Advanced Sl...             500
# 1256                       HealthVit Ashwagandha Powder             155
# 1257                       HealthVit Ashwagandha Powder             155
# 1258     Healthvit Ashwagandha Powder 250mg (Pack of 2)             400
#
#       Discounted Price        Additional_Tags  Ratings Number_of_ratings  \
# 0                  899  FEATURED & BESTSELLER        5               68
# 1                  399  FEATURED & BESTSELLER        4              202
# 2                  299  FEATURED & BESTSELLER        4               96
# 3                  699  FEATURED & BESTSELLER        4              148
# 4                 1715  FEATURED & BESTSELLER        4               28
# ...                ...                    ...      ...               ...
# 1253               700        Rising Products        4                1
# 1255               500        Rising Products        1                1
# 1256               155        Rising Products        5               12
# 1257               155        Rising Products        4                1
# 1258               400        Rising Products        4                1
#
#        Gender         Category Formulation
# 0      Female  Energy-boosters      Tablet
# 1      Unisex  Energy-boosters      Tablet
# 2      Female  Energy-boosters      Tablet
# 3     Unknown  Energy-boosters     Unknown
# 4      Female  Energy-boosters     Unknown
# ...       ...              ...         ...
# 1253   Unisex    Restful Sleep      Tablet
# 1255   Unisex    Restful Sleep      Tablet
# 1256   Unisex    Restful Sleep      Powder
# 1257   Unisex    Restful Sleep      Powder
# 1258   Unisex    Restful Sleep     Unknown
#
# [854 rows x 9 columns]

# %%
# Set the size of the entire figure
plt.figure(figsize=(10, 6))

# Create a stacked bar chart
sns.countplot(x='Category', hue='Gender', data=df)
# Set the title
plt.title("Gender-wise group bar chart for each Category")
# Out:
# Text(0.5, 1.0, 'Gender-wise group bar chart for each Category')

# %%
Insights:
    *In the group bar chart, its evident that energy booster and immunity booster products are predominantly available.
    *Interestingly, in the hormonal balance category, there are no products specifically designed for males.
    *Notably, immunity boosters are not gender-categorized, making them suitable for both males and females.

# %%
pd.crosstab(columns=df['Gender'],index=df['Category'], values=df['Discounted Price'], aggfunc='median')
# Out:
# Gender             Female   Male  Unisex  Unknown
# Category
# Energy-boosters     699.0  574.0   569.0    514.5
# Healthy Heart       962.0  599.0   650.0    614.0
# Hormonal-Balance   1142.0    NaN   968.0    599.0
# Immunity-boosters     NaN    NaN   539.0    537.5
# Restful Sleep       360.0  455.0   579.5    916.0
# Stronger Bones      599.5    NaN   567.0    450.0

# %%
Insights:
    *Energy-boosters & Healthy Heart:
        The mean discounted price for Energy-boosters & Healthy Heart is highest for females, followed by the Unisex category. Males have the lowest mean discounted price.
    *Hormonal-Balance:
        Hormonal-Balance products have the highest mean discounted price for the Unknown category, followed by the Unisex category. Females have a comparatively lower mean discounted price, and the male category is not available (NaN).
    *Immunity-boosters:
        Immunity-boosters have the highest mean discounted price for the Unisex category, followed by the Unknown category. Gender-specific information is not available (NaN).
    *Stronger Bones:
        Stronger Bones products have the highest mean discounted price for females, followed by the Unisex category. 
    *hormonal balance and Stronger bones in the Males category are not available (NaN).

# %%
df['Additional_Tags'].value_counts()
# Out:
# Rising Products          805
# FEATURED & BESTSELLER     25
# FEATURED                  13
# BESTSELLER                11
# Name: Additional_Tags, dtype: int64

# %%
df['Formulation'].value_counts().plot(kind = 'bar', 
                                   figsize = (6,7),
                                   color = ['pink', 'violet', 'orange', 'red', 'black', 'cyan'],
                                  title = 'Number of products availabe in various formulations')
# Out:
# <Axes: title={'center': 'Number of products availabe in various formulations'}>

# %%
Insights:
    *This bar graph gives a quick overview of the range of formulations accessible on the website
    *Capsules and tablet formulations are widely accessible.

# %%
# Set the size of the entire figure
plt.figure(figsize=(10, 6))
a = df[df['Additional_Tags']!='Rising Products']
# Create a stacked bar chart
sns.countplot(x='Category', hue='Additional_Tags', data=a)
# Set the title
plt.title("Category-wise Additional Tags")
# Out:
# Text(0.5, 1.0, 'Category-wise Additional Tags')

# %%
Insights:
    *Energy booster products are prominently featured and are among the best sellers.
    *Interestingly, while the healthy heart category lacks a dedicated "featured" tagline, it stands out as the highest seller.
    *On average, considering both best sellers and featured items, immunity boosters emerge with the highest product count.

# %% [markdown]
# ### Budget friendly products

# %%
pd.crosstab(columns=df['Additional_Tags'],index=df['Category'], values=df['Discounted Price'], aggfunc='mean')
# Out:
# Additional_Tags    BESTSELLER    FEATURED  FEATURED & BESTSELLER  \
# Category
# Energy-boosters           NaN  442.666667             780.666667
# Healthy Heart           559.6         NaN             703.000000
# Hormonal-Balance       1534.5  924.500000             730.750000
# Immunity-boosters      1599.0  551.500000             444.200000
# Restful Sleep           149.5  594.000000             613.000000
# Stronger Bones           99.0  249.333333             615.800000
#
# Additional_Tags    Rising Products
# Category
# Energy-boosters         747.434944
# Healthy Heart           797.891667
# Hormonal-Balance       1383.512195
# Immunity-boosters       842.833333
# Restful Sleep           675.152778
# Stronger Bones          694.364407

# %%
df[(df['Category'] == 'Energy-boosters') & (df['Additional_Tags'] == 'FEATURED & BESTSELLER') & (df['Discounted Price'] <= 781)]
# Out:
#                                        Product_Title  Original Price  \
# 1  HealthKart Hk Vitals Multivitamin For Women, B...             529
# 2  Oziva Daily Women's Multivitamin Tablets For E...             499
# 3           Neuherbs Hair Skin & Vitamins Supplement             999
# 5  Wellbeing Nutrition Daily Greens Wholefood Mul...            1180
#
#    Discounted Price        Additional_Tags  Ratings   Gender         Category  \
# 1               399  FEATURED & BESTSELLER        4   Unisex  Energy-boosters
# 2               299  FEATURED & BESTSELLER        4   Female  Energy-boosters
# 3               699  FEATURED & BESTSELLER        4  Unknown  Energy-boosters
# 5               673  FEATURED & BESTSELLER        5   Unisex  Energy-boosters
#
#   Formulation
# 1      Tablet
# 2      Tablet
# 3     Unknown
# 5     Unknown

# %%
df[(df['Category'] == 'Healthy Heart') & (df['Additional_Tags'] == 'FEATURED & BESTSELLER')& (df['Discounted Price'] <= 703)]
# Out:
#                                          Product_Title  Original Price  \
# 969  Neuherbs Deep Sea Omega 3 Fish Oil 2500mg Caps...            1099
#
#      Discounted Price        Additional_Tags  Ratings   Gender       Category  \
# 969               703  FEATURED & BESTSELLER        5  Unknown  Healthy Heart
#
#     Formulation
# 969     Unknown

# %%
df[(df['Category'] == 'Healthy Heart') & (df['Additional_Tags'] == 'BESTSELLER')& (df['Discounted Price'] <= 560)]
# Out:
#                                          Product_Title  Original Price  \
# 970  HealthKart Hk Vitals Fish Oil Capsules 1000mg ...            1000
# 972  HealthKart Hk Vitals Omega 3, Fish Oil Supplem...             559
# 973               Healthkart Hk Vitals Fish Oil 1000Mg             399
#
#      Discounted Price Additional_Tags  Ratings  Gender       Category  \
# 970               499      BESTSELLER        4  Unisex  Healthy Heart
# 972               356      BESTSELLER        4  Unisex  Healthy Heart
# 973               299      BESTSELLER        5  Unisex  Healthy Heart
#
#     Formulation
# 970     Capsule
# 972     Capsule
# 973     Capsule

# %%
df[(df['Category'] == 'Hormonal-Balance') & (df['Additional_Tags'] == 'FEATURED & BESTSELLER')& (df['Discounted Price'] <= 730)]
# Out:
#                                          Product_Title  Original Price  \
# 656  Be Bodywise PCOS Balance Capsules, Balances Ho...             599
# 657  Power Gummies For That Time Of The Month - Per...             800
#
#      Discounted Price        Additional_Tags  Ratings   Gender  \
# 656               599  FEATURED & BESTSELLER        4  Unknown
# 657               520  FEATURED & BESTSELLER        5   Female
#
#              Category Formulation
# 656  Hormonal-Balance     Unknown
# 657  Hormonal-Balance     Unknown

# %%
df[(df['Category'] == 'Hormonal-Balance') & (df['Additional_Tags'] == 'BESTSELLER')& (df['Discounted Price'] <= 1535)]
# Out:
#                                          Product_Title  Original Price  \
# 661  Be Bodywise PCOS Superfood- Manages Irregular ...             599
#
#      Discounted Price Additional_Tags  Ratings   Gender          Category  \
# 661               569      BESTSELLER        5  Unknown  Hormonal-Balance
#
#     Formulation
# 661     Unknown

# %%
df[(df['Category'] == 'Immunity-boosters') & (df['Additional_Tags'] == 'FEATURED & BESTSELLER')& (df['Discounted Price'] <= 443)]
# Out:
#                                          Product_Title  Original Price  \
# 448  Purna Gummies Vitamin C Orange Gummies with Vi...             499
# 450  Kapiva Ayurveda Wild Amla Juice (Immunity & Di...             299
# 451    Setu 1000mg Vitamin C - 20 Effervescent Tablets             500
#
#      Discounted Price        Additional_Tags  Ratings  Gender  \
# 448                99  FEATURED & BESTSELLER        5  Unisex
# 450               249  FEATURED & BESTSELLER        5  Unisex
# 451               349  FEATURED & BESTSELLER        5  Unisex
#
#               Category Formulation
# 448  Immunity-boosters     Unknown
# 450  Immunity-boosters     Unknown
# 451  Immunity-boosters      Tablet

# %%
df[(df['Category'] == 'Immunity-boosters') & (df['Additional_Tags'] == 'BESTSELLER')& (df['Discounted Price'] <= 1600)]
# Out:
#                                          Product_Title  Original Price  \
# 453  Setu Skin Renew Glutathione With Vitamin C For...            2200
#
#      Discounted Price Additional_Tags  Ratings  Gender           Category  \
# 453              1599      BESTSELLER        4  Unisex  Immunity-boosters
#
#     Formulation
# 453      Tablet

# %%
df[(df['Category'] == 'Restful Sleep') & (df['Additional_Tags'] == 'FEATURED & BESTSELLER')& (df['Discounted Price'] <= 614)]
# Out:
#                                           Product_Title  Original Price  \
# 1133  Wellbeing Nutrition Melts Restful Sleep, Melat...             649
# 1135  PLIX Deep Sleep with Melatonin, Oral Dissolvin...             399
#
#       Discounted Price        Additional_Tags  Ratings  Gender       Category  \
# 1133               565  FEATURED & BESTSELLER        4  Unisex  Restful Sleep
# 1135               379  FEATURED & BESTSELLER        4  Unisex  Restful Sleep
#
#      Formulation
# 1133     Unknown
# 1135      Tablet

# %%
df[(df['Category'] == 'Restful Sleep') & (df['Additional_Tags'] == 'BESTSELLER')& (df['Discounted Price'] <= 150)]
# Out:
#                                           Product_Title  Original Price  \
# 1137  Purna Gummies Melatonin Wild Berry Flavour Gum...             499
#
#       Discounted Price Additional_Tags  Ratings  Gender       Category  \
# 1137                99      BESTSELLER        5  Unisex  Restful Sleep
#
#      Formulation
# 1137     Unknown

# %%
df[(df['Category'] == 'Stronger Bones') & (df['Additional_Tags'] == 'FEATURED & BESTSELLER')& (df['Discounted Price'] <= 616)]
# Out:
#                                          Product_Title  Original Price  \
# 784  OZiva Bettr.CalD3+, Plant-Based Calcium & Vita...             699
# 786  HealthKart Hk Vitals Vitamin D3 (2000 Iu) Caps...             529
# 787  Wellbeing Nutrition Melts Natural Vitamin D3 +...             649
# 788  Dr. Morepen Multivitamins For Women With Calci...             999
#
#      Discounted Price        Additional_Tags  Ratings  Gender        Category  \
# 784               594  FEATURED & BESTSELLER        5  Unisex  Stronger Bones
# 786               399  FEATURED & BESTSELLER        4  Unisex  Stronger Bones
# 787               565  FEATURED & BESTSELLER        5  Unisex  Stronger Bones
# 788               500  FEATURED & BESTSELLER        4  Female  Stronger Bones
#
#     Formulation
# 784     Capsule
# 786     Capsule
# 787     Unknown
# 788      Tablet

# %%
df[(df['Category'] == 'Stronger Bones') & (df['Additional_Tags'] == 'BESTSELLER')& (df['Discounted Price'] <= 100)]
# Out:
#                                          Product_Title  Original Price  \
# 793  Purna Gummies Vitamin C Orange Gummies with Vi...             499
#
#      Discounted Price Additional_Tags  Ratings  Gender        Category  \
# 793                99      BESTSELLER        5  Unisex  Stronger Bones
#
#     Formulation
# 793     Unknown

# %%
# Set the size of the entire figure
plt.figure(figsize=(10, 6))

# Create a stacked bar chart
sns.countplot(x='Category', hue='Ratings', data=df)
# Set the title
plt.title("Ratings for each Category")
# Out:
# Text(0.5, 1.0, 'Ratings for each Category')

# %%
Insights:
    *The majority of products across all categories boast high ratings, predominantly receiving 4 and 5 stars.
    *Notably, there is a scarcity of products with a 2-star rating, indicating a general trend towards favorable customer feedback

# %%
odform = df.groupby(by='Formulation')[['Original Price', 'Discounted Price']].agg('mean')

# %%
dform =df.groupby(by='Formulation')['Discounted Price'].agg('mean')

# %%
ogform = df.groupby(by='Formulation')['Original Price'].agg('mean')

# %%
dform
# Out:
# Formulation
# Capsule     778.912371
# Liquid      593.833333
# Oil         422.500000
# Powder     1036.517241
# Tablet      714.710204
# Unknown     989.322148
# Name: Discounted Price, dtype: float64

# %%
f = np.array(['Capsule', 'Liquid', 'Oil', 'Powder', 'Tablet', 'Unknown'])

# %%
fig, ax = plt.subplots()
ax.bar(f, ogform, label = 'Original Price')
ax.bar(f, dform, bottom=ogform, label = 'Discounted Price')

for bar in ax.patches:
    ax.text(bar.get_x() + bar.get_width() / 2,
          bar.get_height() / 2 + bar.get_y(),
          round(bar.get_height()), ha = 'center',
          color = 'w', weight = 'bold', size = 10)

ax.legend()
ax.set_ylabel('Avg Price')
plt.show()

# %%
Insights :
    Capsules boast the highest discount at 286 units.
    Powders emerge as the most expensive category.
    Oil products, with a discount of 93 units, are the most economical, exhibiting the least discount.

# %%
# Set the size of the entire figure
plt.figure(figsize=(10, 6))
# Create a stacked bar chart
sns.countplot(x='Category', hue='Formulation', data=df)
# Set the title
plt.title("Category-wise Additional Tags")
# Out:
# Text(0.5, 1.0, 'Category-wise Additional Tags')

# %%
Insights:
    *The majority of products across all categories are available in capsule formulation, indicating its widespread popularity.
    *Notably, Stronger Bones exhibit the least variety, being predominantly offered in capsule and tablet forms.
    *Liquid formulations are predominantly found in the Immunity Boosters category.
    *Within the array of available formulations, powder formulations are predominantly concentrated in the Hormonal Balance category. 
    *Within the Hormonal Balance group, you will notice that powder is the preferred option
